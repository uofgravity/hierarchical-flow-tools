# %%
import numpy as np
from glasflow import CouplingNSF
import matplotlib.pyplot as plt
import torch
import seaborn as sns
# torch.use_deterministic_algorithms(True)
torch.manual_seed(1729)
np.random.seed(1729)
sns.set_context("notebook")
sns.set_palette("colorblind")

# %% [markdown]
# # Worked example of hierarchical inference with normalising flows
#
# We wish to infer population parameters $\lambda$ from a set of $N$ gravitational wave observations $\{d\}$. For each set of data $d_i$, we obtain posterior samples $\{\theta_i\}$. Ignoring selection effects, the population posterior is
# $$
# p(\lambda | \{\theta\}) = \prod _ {i = 0} ^ N \frac{1}{S_i} \sum _ {j = 0} ^ {S_i} \frac{\mathcal{L}(\theta_i | \lambda )}{\pi(\theta_i)}.
# $$
#
# Let's train a normalising flow to learn the distribution $\mathcal{L}(\theta_i | \lambda )$.
#
# For a candidate example, we're going to replace everything with Gaussians. Our population is a multivariate, uncorrelated Gaussian with mean $\mu$ and a diagonal covariance matrix with sigmas $\{\sigma_1,...,\sigma_5\}$. Each event is a Gaussian with 0.1 variance and a mean drawn from this population Gaussian.

# %% [markdown]
# ### Training the flow
#
# We train the flow over some boundary of means and variances. We'll say the means are all within [-5, 5] and the variances between [0.5, 2.5]. For each population Gaussian, we draw one posterior sample for one event.

# %%
train_means = np.random.uniform(-5, 5, size=(int(1e6), 5))
train_variances = np.random.uniform(0.5, 2.5, size=(int(1e6), 5))

x_train = np.array([np.random.multivariate_normal(m, np.eye(5)*v) for m,v in zip(train_means, train_variances)])
y_train = np.concatenate([train_means, train_variances], axis=1)

x_scaler = np.vstack([np.mean(x_train,axis=0), np.std(x_train,axis=0)])
y_scaler = np.vstack([np.mean(y_train,axis=0),np.std(y_train,axis=0)])

x_train = (x_train - x_scaler[0]) / x_scaler[1]
y_train = (y_train - y_scaler[0]) / y_scaler[1]

test_means = np.random.uniform(-5, 5, size=(int(1e4), 5))
test_variances = np.random.uniform(0.5, 2.5, size=(int(1e4), 5))

x_val = np.array([np.random.multivariate_normal(m, np.eye(5)*v) for m,v in zip(test_means, test_variances)])
y_val = np.concatenate([test_means, test_variances], axis=1)

x_val = (x_val - x_scaler[0]) / x_scaler[1]
y_val = (y_val - y_scaler[0]) / y_scaler[1]

# %%
batch_size = int(1e5)
device = "cuda:0"
flow = CouplingNSF(
    n_inputs=5,
    n_transforms=4,
    n_conditional_inputs=10,
    n_neurons=32,
    batch_norm_between_transforms=True,
)
flow.to(device)
print(f"Created flow and sent to {device}")
optimiser = torch.optim.Adam(flow.parameters())
# Out:
# Created flow and sent to cuda:0

# %%
x_train_tensor = torch.from_numpy(x_train.astype(np.float32))
y_train_tensor = torch.from_numpy(y_train.astype(np.float32))
train_dataset = torch.utils.data.TensorDataset(x_train_tensor, y_train_tensor)
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True
)

x_val_tensor = torch.from_numpy(x_val.astype(np.float32))
y_val_tensor = torch.from_numpy(y_val.astype(np.float32))
val_dataset = torch.utils.data.TensorDataset(x_val_tensor, y_val_tensor)
val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False
)

# %%
epochs = 50
loss = dict(train=[], val=[])

for i in range(epochs):
    flow.train()
    train_loss = 0.0
    for batch in train_loader:
        x, y = batch
        x = x.to(device)
        y = y.to(device)
        optimiser.zero_grad()
        _loss = -flow.log_prob(x, conditional=y).mean()
        _loss.backward()
        optimiser.step()
        train_loss += _loss.item()
    loss["train"].append(train_loss / len(train_loader))

    flow.eval()
    val_loss = 0.0
    for batch in val_loader:
        x, y = batch
        x = x.to(device)
        y = y.to(device)
        with torch.no_grad():
            _loss = -flow.log_prob(x, conditional=y).mean().item()
        val_loss += _loss
    loss["val"].append(val_loss / len(val_loader))
    if not i % 10:
        print(
            f"Epoch {i} - train: {loss['train'][-1]:.3f}, val: {loss['val'][-1]:.3f}"
        )

flow.eval()
print("Finished training")
# Out:
# OMP: Warning #96: Cannot form a team with 44 threads, using 42 instead.
# OMP: Hint Consider unsetting KMP_DEVICE_THREAD_LIMIT (KMP_ALL_THREADS), KMP_TEAMS_THREAD_LIMIT, and OMP_THREAD_LIMIT (if any are set).
# Epoch 0 - train: 6.756, val: 12.850
# Epoch 10 - train: 2.256, val: 2.251
# Epoch 20 - train: 2.205, val: 2.209
# Epoch 30 - train: 2.194, val: 2.200
# Epoch 40 - train: 2.189, val: 2.197
# Finished training

# %%
plt.plot(loss["train"][5:], label="Train")
plt.plot(loss["val"][5:], label="Val.")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Hierarchical inference
#
# With our trained flow in hand, we're ready to do some hierarchical inference. We'll use the `nessai` nested sampler to infer our 10 hyperparameters, using the flow as a proxy for the likelihood as described earlier.
#
# Our "data" will consist of 10 events with 1000 posterior samples each, where each event mean has been drawn from the population and the variance is 0.1. For ease, we'll just use the first event of our validation set.

# %%
event_mean = test_means[0]
event_variance = test_variances[0]
noise_variance = 0.05
event_samples = np.array([np.random.multivariate_normal(np.random.multivariate_normal(np.random.multivariate_normal(event_mean, np.eye(5)*event_variance),np.eye(5)*noise_variance), np.eye(5)*noise_variance,size=1000) for i in range(10)])

# %%
event_samples_rescaled = (event_samples - x_scaler[0])/x_scaler[1]

# %%
from nessai.flowsampler import FlowSampler
from nessai.model import Model
from nessai.utils import setup_logger
from nessai.plot import corner_plot

# %%
names = [f"mu_{x}" for x in range(1,6)] + [f"sigma_{x}" for x in range(1,6)]
bounds = dict()
for k, n in enumerate(names):
    bounds[n] = [-5, 5] if k < 5 else [0.5,2.5]

# %%
#nessai model class
class GaussianModel(Model):
    def __init__(self, names, bounds, flowlike):
        # Names of parameters to sample
        self.names = names
        # Prior bounds for each parameter
        self.bounds = bounds
        self.flow_lhood = flowlike
        self._vectorised_likelihood = True
        
    def unpack_live_point(self, x):
        start = np.array([x[n] for n in self.names]).T
        if start.ndim == 1:
            start = start[None,:]
        start = (start - y_scaler[0]) / y_scaler[1]
        return torch.Tensor(start).float().to(device)

    def log_prior(self, x):
        """
        Returns log of prior given a live point assuming uniform
        priors on each parameter.
        """
        # Check if values are in bounds, returns True/False
        # Then take the log to get 0/-inf and make sure the dtype is float
        log_p = np.log(self.in_bounds(x), dtype="float").astype(np.float32)
        # Iterate through each parameter (x and y)
        # since the live points are a structured array we can
        # get each value using just the name
        for n in self.names:
            log_p -= np.log(self.bounds[n][1] - self.bounds[n][0])
        return log_p

    def log_likelihood(self, x):
        conditional = self.unpack_live_point(x)
        out = self.flow_lhood.log_likelihood(conditional).cpu().numpy()
        return out

# %%
# %load_ext autoreload
# %autoreload 2
from hierarchical_flows.likelihood import FlowLikelihood
flike = FlowLikelihood(
    flow, device, 
    data=torch.as_tensor(event_samples_rescaled, device=device).float(),
    batch_size=100)
    
model_fast = GaussianModel(names, bounds, flowlike=flike)
output_fast = './outdir_norm_fast'
setup_logger(output=output_fast, log_level='CRITICAL')
fs_fast = FlowSampler(model_fast, output=output_fast, resume=False, seed=1729, nlive=5000)
fs_fast.run()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Drawing live points: 100%|██████████| 5000/5000 [00:04<00:00, 1084.73it/s]
# 12-02 15:34 nessai.nestedsampler CRITICAL: Starting nested sampling loop
# 12-02 15:34 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:35 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:36 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:36 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:36 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:37 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:37 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:37 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:38 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:38 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:39 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:39 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:40 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:40 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:41 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:41 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:42 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:42 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:42 nessai.nestedsampler CRITICAL: Final evidence: -37.960 +/- 0.046
# 12-02 15:42 nessai.nestedsampler CRITICAL: Information: 10.62
# 12-02 15:42 nessai.nestedsampler CRITICAL: Checkpointing nested sampling

# %%
truths = event_mean.tolist() + event_variance.tolist()
corner_fig = corner_plot(
    fs_fast.posterior_samples,
    include=names,
    truths=truths,
    labels=[rf"$\mu_{x}$" for x in range(1,6)] + [rf"$\sigma^2_{x}$" for x in range(1,6)],
)
corner_fig.savefig(output_fast+'/posterior_w_truth.png')
plt.show()

# %% [markdown]
# We have an answer and it looks reasonable. To see if it's trustworthy we can directly perform the hierarchical inference in this case and see if the results are consistent...

# %%
#nessai model class
class HierarchicalModel(Model):
    """A simple two-dimensional Gaussian likelihood."""

    def __init__(self, names, bounds, data):
        # Names of parameters to sample
        self.names = names
        # Prior bounds for each parameter
        self.bounds = bounds
        self.data = torch.as_tensor(data).float().to(device)#.reshape(-1,data.shape[-1])
        self.nsamp = data.shape[1] 
        self.nevents = data.shape[0]
        self._vectorised_likelihood = False #bad 

    def unpack_live_point(self, x):
        start = np.array([x[n] for n in self.names]).T
        if start.ndim == 1:
            start = start[None,:]
        return torch.Tensor(start).float().to(device)

    def log_prior(self, x):
        """
        Returns log of prior given a live point assuming uniform
        priors on each parameter.
        """
        # Check if values are in bounds, returns True/False
        # Then take the log to get 0/-inf and make sure the dtype is float
        log_p = np.log(self.in_bounds(x), dtype="float").astype(np.float32)
        # Iterate through each parameter (x and y)
        # since the live points are a structured array we can
        # get each value using just the name
        for n in self.names:
            log_p -= np.log(self.bounds[n][1] - self.bounds[n][0])
        return log_p

    def log_likelihood(self, x):
        try:
            if len(x[self.names[0]]) > 1:
                raise NotImplementedError
        except TypeError:
            pass
        conditional = self.unpack_live_point(x)
        log_prob = 0
        for event_data in self.data:
            with torch.no_grad():
                diff = (event_data - conditional[:,:5])
                detcov = torch.prod(conditional[:,5:],dim=-1)
                probs = -0.5*(diff**2 * conditional[:,5:]**-1).sum(axis=-1) - 0.5*torch.log(detcov) - 5/2 * np.log(2*np.pi)
                log_prob += (torch.logsumexp(probs,dim=-1).cpu().numpy() - np.log(self.nsamp))
        return log_prob

# %%
model2 = HierarchicalModel(names, bounds, data=event_samples)
output2 = './outdir_norm_hierarchical'
setup_logger(output=output2, log_level='WARNING')
fs2 = FlowSampler(model2, output=output2, resume=False, seed=1729, nlive=5000)
fs2.run()
# Out:
# 12-02 15:45 nessai.nestedsampler WARNING : Proposal will only train when empty
# Drawing live points: 100%|██████████| 5000/5000 [00:13<00:00, 373.89it/s]
# 12-02 15:45 nessai.nestedsampler CRITICAL: Starting nested sampling loop
# 12-02 15:45 nessai.nestedsampler WARNING : it:  5000: n eval: 15000 H: 5.16 dZ: 269.147 logZ: -358.940 +/- 0.032 logLmax: -88.79
# 12-02 15:45 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:45 nessai.nestedsampler WARNING : Rolling KS test: D=0.01, p-value=0.3654
# 12-02 15:46 nessai.nestedsampler WARNING : it: 10000: n eval: 40000 H: 5.38 dZ: 150.803 logZ: -241.596 +/- 0.033 logLmax: -88.79
# 12-02 15:46 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:46 nessai.nestedsampler WARNING : Rolling KS test: D=0.0032, p-value=0.9007
# 12-02 15:47 nessai.nestedsampler WARNING : Switching to FlowProposal
# 12-02 15:48 nessai.nestedsampler WARNING : it: 15000: n eval: 59516 H: 5.75 dZ: 93.209 logZ: -181.353 +/- 0.034 logLmax: -85.14
# 12-02 15:48 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:48 nessai.nestedsampler WARNING : Rolling KS test: D=0.0024, p-value=0.9425
# 12-02 15:48 nessai.nestedsampler WARNING : it: 20000: n eval: 67123 H: 6.27 dZ: 58.084 logZ: -147.193 +/- 0.035 logLmax: -85.11
# 12-02 15:48 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:48 nessai.nestedsampler WARNING : Rolling KS test: D=0.0232, p-value=0.004524
# 12-02 15:49 nessai.nestedsampler WARNING : it: 25000: n eval: 82927 H: 6.74 dZ: 39.422 logZ: -126.513 +/- 0.037 logLmax: -82.09
# 12-02 15:49 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:49 nessai.nestedsampler WARNING : Rolling KS test: D=0.0094, p-value=0.4107
# 12-02 15:50 nessai.evidence WARNING : NS integrator received non-monotonic logL.-109.72509 -> -109.72509
# 12-02 15:50 nessai.nestedsampler WARNING : it: 30000: n eval: 90627 H: 7.21 dZ: 26.538 logZ: -114.629 +/- 0.038 logLmax: -82.09
# 12-02 15:50 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:50 nessai.nestedsampler WARNING : Rolling KS test: D=0.0144, p-value=0.1245
# 12-02 15:51 nessai.evidence WARNING : NS integrator received non-monotonic logL.-99.04776 -> -99.04776
# 12-02 15:51 nessai.nestedsampler WARNING : it: 35000: n eval: 106915 H: 7.68 dZ: 17.997 logZ: -107.088 +/- 0.039 logLmax: -82.09
# 12-02 15:51 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:51 nessai.nestedsampler WARNING : Rolling KS test: D=0.008, p-value=0.5245
# 12-02 15:51 nessai.nestedsampler WARNING : it: 40000: n eval: 115125 H: 8.13 dZ: 13.192 logZ: -102.523 +/- 0.040 logLmax: -81.33
# 12-02 15:51 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:51 nessai.nestedsampler WARNING : Rolling KS test: D=0.0042, p-value=0.8359
# 12-02 15:51 nessai.evidence WARNING : NS integrator received non-monotonic logL.-93.17685 -> -93.17685
# 12-02 15:52 nessai.evidence WARNING : NS integrator received non-monotonic logL.-91.10037 -> -91.10037
# 12-02 15:52 nessai.nestedsampler WARNING : it: 45000: n eval: 131688 H: 8.63 dZ: 9.317 logZ: -99.648 +/- 0.042 logLmax: -81.33
# 12-02 15:52 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:52 nessai.nestedsampler WARNING : Rolling KS test: D=0.015, p-value=0.1043
# 12-02 15:53 nessai.evidence WARNING : NS integrator received non-monotonic logL.-89.16257 -> -89.16257
# 12-02 15:53 nessai.evidence WARNING : NS integrator received non-monotonic logL.-88.73674 -> -88.73674
# 12-02 15:53 nessai.evidence WARNING : NS integrator received non-monotonic logL.-88.02077 -> -88.02077
# 12-02 15:53 nessai.evidence WARNING : NS integrator received non-monotonic logL.-87.73650 -> -87.73650
# 12-02 15:54 nessai.nestedsampler WARNING : it: 50000: n eval: 149151 H: 9.07 dZ: 6.473 logZ: -97.802 +/- 0.043 logLmax: -81.33
# 12-02 15:54 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:54 nessai.nestedsampler WARNING : Rolling KS test: D=0.0202, p-value=0.01667
# 12-02 15:54 nessai.evidence WARNING : NS integrator received non-monotonic logL.-87.43330 -> -87.43330
# 12-02 15:54 nessai.evidence WARNING : NS integrator received non-monotonic logL.-87.02372 -> -87.02372
# 12-02 15:54 nessai.evidence WARNING : NS integrator received non-monotonic logL.-86.90490 -> -86.90490
# 12-02 15:54 nessai.evidence WARNING : NS integrator received non-monotonic logL.-86.83869 -> -86.83869
# 12-02 15:54 nessai.evidence WARNING : NS integrator received non-monotonic logL.-86.60111 -> -86.60111
# 12-02 15:54 nessai.evidence WARNING : NS integrator received non-monotonic logL.-85.85174 -> -85.85174
# 12-02 15:54 nessai.nestedsampler WARNING : it: 55000: n eval: 157575 H: 9.45 dZ: 4.831 logZ: -96.675 +/- 0.043 logLmax: -80.85
# 12-02 15:54 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:54 nessai.nestedsampler WARNING : Rolling KS test: D=0.0248, p-value=0.002096
# 12-02 15:55 nessai.evidence WARNING : NS integrator received non-monotonic logL.-84.71294 -> -84.71294
# 12-02 15:55 nessai.nestedsampler WARNING : it: 60000: n eval: 175120 H: 9.77 dZ: 3.188 logZ: -95.999 +/- 0.044 logLmax: -80.85
# 12-02 15:55 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:55 nessai.nestedsampler WARNING : Rolling KS test: D=0.0108, p-value=0.3093
# 12-02 15:55 nessai.evidence WARNING : NS integrator received non-monotonic logL.-84.29724 -> -84.29724
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-84.21747 -> -84.21747
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-84.19980 -> -84.19980
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-84.02462 -> -84.02462
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.88269 -> -83.88269
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.86966 -> -83.86966
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.77148 -> -83.77148
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.73896 -> -83.73896
# 12-02 15:56 nessai.nestedsampler WARNING : it: 65000: n eval: 192848 H: 10.05 dZ: 1.989 logZ: -95.587 +/- 0.045 logLmax: -80.75
# 12-02 15:56 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:56 nessai.nestedsampler WARNING : Rolling KS test: D=0.0216, p-value=0.009276
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.71476 -> -83.71476
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.70180 -> -83.70180
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.65201 -> -83.65201
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.64449 -> -83.64449
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.63494 -> -83.63494
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.48505 -> -83.48505
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.34774 -> -83.34774
# 12-02 15:56 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.31777 -> -83.31777
# 12-02 15:57 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.26096 -> -83.26096
# 12-02 15:57 nessai.evidence WARNING : NS integrator received non-monotonic logL.-83.10976 -> -83.10976
# 12-02 15:57 nessai.nestedsampler WARNING : it: 70000: n eval: 201739 H: 10.27 dZ: 1.285 logZ: -95.341 +/- 0.045 logLmax: -80.38
# 12-02 15:57 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:57 nessai.nestedsampler WARNING : Rolling KS test: D=0.0104, p-value=0.3367
# 12-02 15:57 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.81250 -> -82.81250
# 12-02 15:57 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.72651 -> -82.72651
# 12-02 15:57 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.70578 -> -82.70578
# 12-02 15:57 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.66972 -> -82.66972
# 12-02 15:57 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.62705 -> -82.62705
# 12-02 15:57 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.60570 -> -82.60570
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.48759 -> -82.48759
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.47981 -> -82.47981
# 12-02 15:58 nessai.nestedsampler WARNING : it: 75000: n eval: 218862 H: 10.44 dZ: 0.607 logZ: -95.199 +/- 0.046 logLmax: -80.38
# 12-02 15:58 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:58 nessai.nestedsampler WARNING : Rolling KS test: D=0.0128, p-value=0.1926
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.42450 -> -82.42450
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.38461 -> -82.38461
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.34377 -> -82.34377
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.33688 -> -82.33688
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.31578 -> -82.31578
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.28182 -> -82.28182
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.20914 -> -82.20914
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.20153 -> -82.20153
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.19588 -> -82.19588
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.18905 -> -82.18905
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.15438 -> -82.15438
# 12-02 15:58 nessai.evidence WARNING : NS integrator received non-monotonic logL.-82.13023 -> -82.13023
# 12-02 15:58 nessai.nestedsampler WARNING : it: 80000: n eval: 227347 H: 10.55 dZ: 0.252 logZ: -95.121 +/- 0.046 logLmax: -80.37
# 12-02 15:58 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 15:58 nessai.nestedsampler WARNING : Rolling KS test: D=0.0128, p-value=0.1926
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.99008 -> -81.99008
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.97660 -> -81.97660
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.96301 -> -81.96301
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.92191 -> -81.92191
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.90925 -> -81.90925
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.85402 -> -81.85402
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.84157 -> -81.84157
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.83636 -> -81.83636
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.81917 -> -81.81917
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.81632 -> -81.81632
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.81449 -> -81.81449
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.79306 -> -81.79306
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.78378 -> -81.78378
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.75640 -> -81.75640
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.75320 -> -81.75320
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.73938 -> -81.73938
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.73629 -> -81.73629
# 12-02 15:59 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.73509 -> -81.73509
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.70817 -> -81.70817
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.70632 -> -81.70632
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.65012 -> -81.65012
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.64609 -> -81.64609
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.63778 -> -81.63778
# 12-02 16:00 nessai.nestedsampler WARNING : it: 85000: n eval: 244686 H: 10.62 dZ: 0.106 logZ: -95.079 +/- 0.046 logLmax: -80.27
# 12-02 16:00 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 16:00 nessai.nestedsampler WARNING : Rolling KS test: D=0.014, p-value=0.1396
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.59746 -> -81.59746
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.58790 -> -81.58790
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.53009 -> -81.53009
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.49730 -> -81.49730
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.41413 -> -81.41413
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.40840 -> -81.40840
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.37694 -> -81.37694
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.36515 -> -81.36515
# 12-02 16:00 nessai.evidence WARNING : NS integrator received non-monotonic logL.-81.21092 -> -81.21092
# 12-02 16:00 nessai.nestedsampler WARNING : it: 85309: n eval: 244686 H: 10.70 dZ: 0.100 logZ: -95.041 +/- 0.046 logLmax: -80.27
# 12-02 16:00 nessai.nestedsampler CRITICAL: Checkpointing nested sampling
# 12-02 16:00 nessai.nestedsampler CRITICAL: Final evidence: -95.041 +/- 0.046
# 12-02 16:00 nessai.nestedsampler CRITICAL: Information: 10.70
# 12-02 16:00 nessai.nestedsampler WARNING : Final KS test: D=0.004906, p-value=0.0164
# 12-02 16:00 nessai.nestedsampler CRITICAL: Checkpointing nested sampling

# %%
truths = event_mean.tolist() + event_variance.tolist()
corner_fig = corner_plot(
    fs2.posterior_samples,
    include=names,
    truths=truths,
    labels=[rf"$\mu_{x}$" for x in range(1,6)] + [rf"$\sigma^2_{x}$" for x in range(1,6)]
)

# %%
pal = sns.color_palette(palette="colorblind").as_hex()

truths = event_mean.tolist() + event_variance.tolist()
corner_fig = corner_plot(
    fs2.posterior_samples,
    color=pal[1],
    include=names,
    truths=truths,
    labels=[rf"$\mu_{x}$" for x in range(1,6)] + [rf"$\sigma^2_{x}$" for x in range(1,6)],
    hist_kwargs=dict(density=True,color=pal[1]),
    plot_density=False,
    plot_datapoints=False,
    fill_contours=False,
    levels = (1 - np.exp(-0.5), 1-np.exp(-2))
)

corner_fig2 = corner_plot(
    fs_fast.posterior_samples,
    color=pal[0],
    include=names,
    truths=truths,
    labels=[rf"$\mu_{x}$" for x in range(1,6)] + [rf"$\sigma^2_{x}$" for x in range(1,6)],
    fig = corner_fig,
    hist_kwargs=dict(density=True,color=pal[0]),
    plot_density=False,
    plot_datapoints=False,
    fill_contours=False,
    levels = (1 - np.exp(-0.5), 1-np.exp(-2))
)

import matplotlib.lines as mlines
blue = mlines.Line2D([],[], color=pal[0], label='Normalising flow')
orange = mlines.Line2D([],[], color=pal[1], label='Hierarchical Inference')
corner_fig2.legend(handles=[blue, orange], loc=(0.37,0.85),fontsize=32, frameon=False)
corner_fig2.savefig('joint_posterior_w_truth.png')
plt.show()
